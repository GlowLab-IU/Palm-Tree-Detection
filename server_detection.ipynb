# %%
cd "/content/drive/MyDrive/[project]/[Model_Palm]/[Model_detection]"
# Out:
# /content/drive/MyDrive/[project]/[Model_Palm]/[Model_detection]

# %%
pip install -r "requirements.txt"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 44.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.7/111.7 kB 10.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.8/510.8 kB 34.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 MB 14.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 118.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.2/452.2 kB 34.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 10.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.12.0.88
#     Uninstalling opencv-python-4.12.0.88:
#       Successfully uninstalled opencv-python-4.12.0.88
# ...

# %%
import os
from google.colab import userdata

os.environ['USE_NGROK'] = 'true'

os.environ['NGROK_AUTHTOKEN'] = userdata.get('NGROK_AUTHTOKEN')
os.environ['NGROK_DOMAIN'] = userdata.get('NGROK_DOMAIN')

# !python3 server.py
# Out:
# 2025-09-27 10:59:33,719 - INFO - ⏳ Đang tải model từ './best_palmtree.pt' trên thiết bị 'CUDA'...
# 2025-09-27 10:59:34,329 - INFO - ✅ Tải model thành công!
# 2025-09-27 10:59:34,336 - INFO - Overriding default auth token
# 2025-09-27 10:59:34,350 - INFO - t=2025-09-27T10:59:34+0000 lvl=info msg="no configuration paths supplied"
# 2025-09-27 10:59:34,350 - INFO - t=2025-09-27T10:59:34+0000 lvl=info msg="using configuration at default config path" path=/root/.config/ngrok/ngrok.yml
# 2025-09-27 10:59:34,350 - INFO - t=2025-09-27T10:59:34+0000 lvl=info msg="open config file" path=/root/.config/ngrok/ngrok.yml err=nil
# 2025-09-27 10:59:34,372 - INFO - t=2025-09-27T10:59:34+0000 lvl=info msg="starting web service" obj=web addr=127.0.0.1:4040 allow_hosts=[]
# 2025-09-27 10:59:34,798 - INFO - t=2025-09-27T10:59:34+0000 lvl=info msg="client session established" obj=tunnels.session
# ...
